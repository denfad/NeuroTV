# %%
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
import warnings
warnings.filterwarnings("ignore")
sns.set(context='notebook', style='whitegrid', palette='deep', 
        font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
df_data = pd.read_csv('data.csv', sep=';')
df_params = pd.read_csv('params.csv', sep=';')
df_regions = pd.read_csv('regions.csv', sep=';')

# %%
df_params.index = df_params.id
dict_params = df_params['name'].to_dict()
df_data['param_id'] = df_data['param_id'].apply(lambda x: dict_params[x])
df_regions.index = df_regions.id
dict_regions = df_regions['name'].to_dict()
dict_upid = df_regions['upid'].to_dict()
df_data['upid'] = df_data['region_id'].apply(lambda x: dict_upid[x])
df_data['region_id'] = df_data['region_id'].apply(lambda x: dict_regions[x])
df_data
# Out:
#                                                 param_id  \
# 0                          Плотность населения; чел./км2
# 1                          Плотность населения; чел./км2
# 2                          Плотность населения; чел./км2
# 3                          Плотность населения; чел./км2
# 4                          Плотность населения; чел./км2
# ...                                                  ...
# 52171  Среднегодовой курс доллара США (по данным ЦБ Р...
# 52172  Среднегодовой курс доллара США (по данным ЦБ Р...
# 52173  Среднегодовой курс доллара США (по данным ЦБ Р...
# 52174  Среднегодовой курс доллара США (по данным ЦБ Р...
# 52175  Среднегодовой курс доллара США (по данным ЦБ Р...
#
#                              region_id  year_id    value  upid
# 0                       Алтайский край     2007  14.7200     1
# 1                       Алтайский край     2008  14.6040     1
# 2                       Алтайский край     2009  14.5170     1
# 3                       Алтайский край     2010  14.3870     1
# 4                       Алтайский край     2011  14.3890     1
# ...                                ...      ...      ...   ...
# 52171  Ямало-Ненецкий автономный округ     2013  31.8496     9
# 52172  Ямало-Ненецкий автономный округ     2014  38.4667     9
# 52173  Ямало-Ненецкий автономный округ     2015  61.2946     9
# 52174  Ямало-Ненецкий автономный округ     2016  67.1899     9
# 52175  Ямало-Ненецкий автономный округ     2017  58.3086     9
#
# [52176 rows x 5 columns]
